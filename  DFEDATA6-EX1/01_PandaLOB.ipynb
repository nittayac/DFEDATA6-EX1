# %% [markdown]
# <a href="https://colab.research.google.com/github/nittayac/DFEDATA6-EX1/blob/main/%20DFEDATA6-EX1/01_PandaLOB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = pd.read_csv("https://raw.githubusercontent.com/a-forty-two/cylons/master/data.csv")
data.head()
data.tail()
# Out:
#          id diagnosis  ...  fractal_dimension_worst  Unnamed: 32
# 564  926424         M  ...                  0.07115          NaN
# 565  926682         M  ...                  0.06637          NaN
# 566  926954         M  ...                  0.07820          NaN
# 567  927241         M  ...                  0.12400          NaN
# 568   92751         B  ...                  0.07039          NaN
#
# [5 rows x 33 columns]
